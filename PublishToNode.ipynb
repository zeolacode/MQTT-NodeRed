# %%
pip install paho-mqtt
# Out:
# ...
#      |████████████████████████████████| 99 kB 4.9 MB/s
# ...
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62133 sha256=fdef2c2734766978d475a3050f8b11479692bbb4660579fb559716443b50e366
#   Stored in directory: /root/.cache/pip/wheels/d0/bf/ac/2b3f43f8c6fcd0f4ba5395397458c521eb0b52d33b574a5a40
# Successfully built paho-mqtt
# ...

# %%
from google.colab import drive
drive.mount('Mydrive')
# Out:
# Mounted at Mydrive

# %%
import pandas as pd
import numpy as np

# %%
import paho.mqtt.client as mqtt 
from random import randrange, uniform
import time

# %%
mqttBroker ="mqtt.eclipseprojects.io" 

client = mqtt.Client("Sensor_simulation_3W")
client.connect(mqttBroker)
# Out:
# 0

# %%
'''
while True:
    randNumber = uniform(20.0, 21.0)
    client.publish("DATA_3W", randNumber)
    print("Just published " + str(randNumber) + " to topic DATA_3W")
    time.sleep(1)


'''
# Out:
# '\nwhile True:\n    randNumber = uniform(20.0, 21.0)\n    client.publish("DATA_3W", randNumber)\n    print("Just published " + str(randNumber) + " to topic DATA_3W")\n    time.sleep(1)\n\n\n'

# %%
df = pd.read_csv('/content/Mydrive/MyDrive/projetos/PRH-21/WELL-00020_20120410192326.csv')

# %%
df = df.fillna(0)
df
# Out:
#                         timestamp         P-PDG  ...       QGL  class
# 0      2012-04-10 19:23:26.000000  2.157054e+09  ...  0.056527    0.0
# 1      2012-04-10 19:23:27.000000  2.157074e+09  ...  0.056532    0.0
# 2      2012-04-10 19:23:28.000000  2.157094e+09  ...  0.056537    0.0
# 3      2012-04-10 19:23:29.000000  2.157114e+09  ...  0.056542    0.0
# 4      2012-04-10 19:23:30.000000  2.157134e+09  ...  0.056547    0.0
# ...                           ...           ...  ...       ...    ...
# 15683  2012-04-10 23:44:49.000000  2.309476e+09  ...  0.000202    8.0
# 15684  2012-04-10 23:44:50.000000  2.309482e+09  ...  0.000202    8.0
# 15685  2012-04-10 23:44:51.000000  2.309488e+09  ...  0.000202    8.0
# 15686  2012-04-10 23:44:52.000000  2.309494e+09  ...  0.000201    8.0
# 15687  2012-04-10 23:44:53.000000  2.309500e+09  ...  0.000201    8.0
#
# [15688 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['timestamp', 'P-PDG', 'P-TPT', 'T-TPT', 'P-MON-CKP', 'T-JUS-CKP',
#        'P-JUS-CKGL', 'T-JUS-CKGL', 'QGL', 'class'],
#       dtype='object')

# %%
  np_P_PDG = np.array(df['P-PDG'])
  np_P_TPT = np.array(df['P-TPT'])
  np_T_TPT = np.array(df['T-TPT'])
  np_P_MON_CKP = np.array(df['P-MON-CKP'])
  np_T_JUS_CKP = np.array(df['T-JUS-CKP'])
  np_P_JUS_CKGL = np.array(df['P-JUS-CKGL'])
  np_T_JUS_CKGL = np.array(df['T-JUS-CKGL'])
  np_QGL = np.array(df['QGL'])
  #timestamp = np.array(df['timestamp'])

# %%
import json

# %%
mqttBroker ="mqtt.eclipseprojects.io" 

client = mqtt.Client("Sensor_simulation_3W")
client.connect(mqttBroker)

for i in range(0, 15688):
  DATA_3W = {"P_PDG":np_P_PDG[i], 
             "P_TPT":np_P_TPT[i], 
             "T_TPT":np_T_TPT[i], 
             "P_MON_CKP":np_P_MON_CKP[i], 
             "T_JUS_CKP":np_T_JUS_CKP[i],
             "P_JUS_CKGL":np_P_JUS_CKGL[i],
             "T_JUS_CKGL":np_T_JUS_CKGL[i],
             "QGL":np_QGL[i],
             "device_id": 8
             }
  client.publish("DATA_3W", json.dumps(DATA_3W))
  print("Just published " +  json.dumps(DATA_3W) + "to topic DATA_3W")
  time.sleep(1)
# Out:
# Just published {"P_PDG": 2157054000.0, "P_TPT": 684335400.0, "T_TPT": 59.245380000000004, "P_MON_CKP": 1625144.0, "T_JUS_CKP": 0.0, "P_JUS_CKGL": 1551768000.0, "T_JUS_CKGL": 0.0, "QGL": 0.05652693, "device_id": 8}to topic DATA_3W
# Just published {"P_PDG": 2157074000.0, "P_TPT": 684189700.0, "T_TPT": 59.27158000000001, "P_MON_CKP": 1623155.0, "T_JUS_CKP": 0.0, "P_JUS_CKGL": 1551785000.0, "T_JUS_CKGL": 0.0, "QGL": 0.05653206, "device_id": 8}to topic DATA_3W
# Just published {"P_PDG": 2157094000.0, "P_TPT": 684043900.0, "T_TPT": 59.29778, "P_MON_CKP": 1621166.0, "T_JUS_CKP": 0.0, "P_JUS_CKGL": 1551802000.0, "T_JUS_CKGL": 0.0, "QGL": 0.05653719, "device_id": 8}to topic DATA_3W
# Just published {"P_PDG": 2157114000.0, "P_TPT": 683898200.0, "T_TPT": 59.323969999999996, "P_MON_CKP": 1619176.0, "T_JUS_CKP": 0.0, "P_JUS_CKGL": 1551819000.0, "T_JUS_CKGL": 0.0, "QGL": 0.05654232, "device_id": 8}to topic DATA_3W
# ...

# %%
a = np.array(DATA_3W)

# %%
a
# Out:
# array({'P-PDG': 2157054000.0, 'P-TPT': 684335400.0, 'T-TPT': 59.245380000000004, 'P-MON-CKP': 1625144.0, 'T-JUS-CKP': nan, 'P-JUS-CKGL': 1551768000.0, 'T-JUS-CKGL': nan, 'QGL': 0.05652693},
#       dtype=object)

# %%
json.dumps(DATA_3W)
# Out:
# '{"P_PDG": 2157234000.0, "P_TPT": 683188000.0, "T_TPT": 59.48114, "P_MON_CKP": 1613986.0, "T_JUS_CKP": NaN, "P_JUS_CKGL": 1551340000.0, "T_JUS_CKGL": NaN, "QGL": 0.05656184, "device_id": 10}'

# %%
client.publish()

# %%
a = mydict

# %% [markdown]
# # features

# %%
a = {
    "P_PDG": 2157054000,
    "P_TPT": 684335400,
    "T_TPT": 59.245380000000004,
    "P_MON_CKP": 1625144,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1551768000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05652693
},{
    "P_PDG": 2157074000,
    "P_TPT": 684189700,
    "T_TPT": 59.27158000000001,
    "P_MON_CKP": 1623155,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1551785000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05653206
},{
    "P_PDG": 2157094000,
    "P_TPT": 684043900,
    "T_TPT": 59.29778,
    "P_MON_CKP": 1621166,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1551802000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05653719
},{
    "P_PDG": 2157114000,
    "P_TPT": 683898200,
    "T_TPT": 59.323969999999996,
    "P_MON_CKP": 1619176,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1
,
    "T_JUS_CKGL": 0,
    "QGL": 0.05665966
},{
    "P_PDG": 2157932000,
    "P_TPT": 679236900,
    "T_TPT": 60.39799,
    "P_MON_CKP": 1606808,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548721000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05666253
},{
    "P_PDG": 2157952000,
    "P_TPT": 679124000,
    "T_TPT": 60.42419,
    "P_MON_CKP": 1607690,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548706000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05666541
},{
    "P_PDG": 2157972000,
    "P_TPT": 679011100,
    "T_TPT": 60.450390000000006,
    "P_MON_CKP": 1608572,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548692000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05666829
},{
    "P_PDG": 2157992000,
    "P_TPT": 678898200,
    "T_TPT": 60.47659,
    "P_MON_CKP": 1609455,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548678000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05667116
},{
    "P_PDG": 2158012000,
    "P_TPT": 678785400,
    "T_TPT": 60.50278,
    "P_MON_CKP": 1610337,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548663000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05667404
},{
    "P_PDG": 2158032000,
    "P_TPT": 678672500,
    "T_TPT": 60.528980000000004,
    "P_MON_CKP": 1611219,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548649000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05667692
},{
    "P_PDG": 2158052000,
    "P_TPT": 678559600,
    "T_TPT": 60.55517,
    "P_MON_CKP": 1612101,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548635000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05667979
},{
    "P_PDG": 2158072000,
    "P_TPT": 678446700,
    "T_TPT": 60.58136999999999,
    "P_MON_CKP": 1612984,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548620000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05668267
},{
    "P_PDG": 2158092000,
    "P_TPT": 678333800,
    "T_TPT": 60.60756,
    "P_MON_CKP": 1613866,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548606000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05668555
},{
    "P_PDG": 2158112000,
    "P_TPT": 678220900,
    "T_TPT": 60.633759999999995,
    "P_MON_CKP": 1614748,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548592000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05668842
},{
    "P_PDG": 2158132000,
    "P_TPT": 678108000,
    "T_TPT": 60.65995,
    "P_MON_CKP": 1615630,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548577000,
    "T_JUS_CKGL": 0,
    "QGL": 0.0566913
},{
    "P_PDG": 2158152000,
    "P_TPT": 677995100,
    "T_TPT": 60.68615,
    "P_MON_CKP": 1616513,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548563000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05669418
},{
    "P_PDG": 2158172000,
    "P_TPT": 677882200,
    "T_TPT": 60.71235,
    "P_MON_CKP": 1617395,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548549000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05669705
},{
    "P_PDG": 2158192000,
    "P_TPT": 677769300,
    "T_TPT": 60.73854,
    "P_MON_CKP": 1618277,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548534000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05669993
},{
    "P_PDG": 2158212000,
    "P_TPT": 677656400,
    "T_TPT": 60.76474,
    "P_MON_CKP": 1619159,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548520000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05670281
},{
    "P_PDG": 2158232000,
    "P_TPT": 677543600,
    "T_TPT": 60.79093,
    "P_MON_CKP": 1620042,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548506000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05670569
},{
    "P_PDG": 2158252000,
    "P_TPT": 677430700,
    "T_TPT": 60.817130000000006,
    "P_MON_CKP": 1620924,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548491000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05670856
},{
    "P_PDG": 2158272000,
    "P_TPT": 677317800,
    "T_TPT": 60.84332,
    "P_MON_CKP": 1621806,
    "T_JUS_CKP": 0,
    "P_JUS_CKGL": 1548477000,
    "T_JUS_CKGL": 0,
    "QGL": 0.05671144
},

# %%
a[2]
# Out:
# {'P_JUS_CKGL': 1551802000,
#  'P_MON_CKP': 1621166,
#  'P_PDG': 2157094000,
#  'P_TPT': 684043900,
#  'QGL': 0.05653719,
#  'T_JUS_CKGL': 0,
#  'T_JUS_CKP': 0,
#  'T_TPT': 59.29778}
